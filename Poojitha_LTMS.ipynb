# %%
# %cd /content/drive/MyDrive/Project_SM/
# Out:
# /content/drive/MyDrive/Project_SM

# %%
from configs import *

# %%
print(file_name)
print(embedding_file)
print(training_ratio)
print(maximum_len)
print(hidden_size)
print(batch_size)
print(epochs)
print(learning_rate)
# Out:
# clean_data.csv
# GoogleNews-vectors-negative300.bin.gz
# 0.8
# 1000
# 50
# 100
# 200
# 0.01

# %%
# %matplotlib inline
# %run poojitha_manhattan_lstm.py
# Out:
# loading_data
# Training Samples in the dataframe: 4566
# Validation Samples in the dataframe : 1142
# Maximum sequence length           : 303
# Building Embedding Matrix
# Defining the LSRTM Model
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# sequence1 (InputLayer)          [(None, 303)]        0
# __________________________________________________________________________________________________
# sequence2 (InputLayer)          [(None, 303)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 303, 300)     3201600     sequence1[0][0]
#                                                                  sequence2[0][0]
# __________________________________________________________________________________________________
# ...

# %%
print(file_name)
print(embedding_file)
print(training_ratio)
print(maximum_len)
print(hidden_size)
print(batch_size)
print(epochs)
print(learning_rate)
